# %% [markdown]
# ## 01 Basic packages

# %%
'''Dataframe and matrix'''

import pandas as pd

import numpy as np


'''Spatial analysis'''

import geopandas as gp

from shapely.geometry import Point, Polygon

import networkx as nx

import folium

import h3


'''Mathmatical calculation'''

import math

import random

import pulp

'''Systemic tools'''

import copy

import os, sys

# %% [markdown]
# ## 02 Spatial methods

# %%
'''Get travel distance'''

def Get_distance(point1,point2):
    
    return Point(point1).distance(Point(point2))*111000*1.2

'''Get travel time'''

def Get_travel_time(dis,speed):
    
    return int(dis/speed)

'''Hexagonal classes'''

class Hexagon(object):
    
    '''
    Functions:
    
    (1) convert geographical coordinates to hexgon
    
    (2) Generate a set of neighbor hexagons for the given hexgon
    
    '''
    
    def __init__(self,resolution):
        
        self.resolution=resolution
        
    def Get_Hex(self,lat,lng):
        
        '''
        Input: latitude,longitude
        
        Output: hexgon
        
        '''
        
        return h3.geo_to_h3(lat,lng,self.resolution)
    
    def Get_Neigh(self,hexgon,radius):
        
        '''
        Input: central hexgon,radius
        
        Output: set of neighbor hexgons
        
        '''
        
        y= h3.hex_range_distances(hexgon, radius)
        
        x=list()
        for y_ in y:
            for y__ in y_:
                x.append(y__)
        return x
    
    def Compact_lists(self,hexagons):
        
        '''
        Input: list of hexgons
        
        Output: set of hexgons
        
        '''
        
        result=list()
    
        for a in hexagons:

            result=list(set(result+a))

        return result
    
    def Center_point(self,hexagon):
        
        return [p for p in h3.h3_to_geo(hexagon)]
    
    def Sample_point(self,hexagon):
        
        '''
        Input: hexgon
        
        Output: point
        
        '''
        
        boundary=h3.h3_to_geo_boundary(hexagon)
        poly = Polygon(boundary)
        (minx, miny, maxx, maxy) = poly.bounds
        while True:
            p = Point(random.uniform(minx, maxx), random.uniform(miny, maxy))
            if poly.contains(p):
                return [list(p.coords)[0][0],list(p.coords)[0][1]]

# %% [markdown]
# ## 03 Optimization matching

# %%
'''Order dispatching algorithm'''

def One2One_Matching(Utility):

    '''Define the problem'''

    model = pulp.LpProblem("Ride_Matching_Problems", pulp.LpMaximize)

    '''Construct our decision variable lists'''

    X = pulp.LpVariable.dicts("X",((O, D) for O in Utility.keys() for D in Utility[O].keys()),lowBound=0,upBound=1,cat='Integer')

    '''Objective Function'''

    model += (pulp.lpSum([Utility[O][D] * X[(O, D)] for O in Utility.keys() for D in Utility[O].keys()]))
    
    '''Each order can only be assigned one driver'''

    for O in Utility.keys():

        model += pulp.lpSum([X[(O, D)] for D in Utility[O].keys()]) <=1

    '''Each driver can only serve one order'''
    
    Utility_={}
    
    for O in Utility.keys():
        for D in Utility[O].keys():
            if D not in Utility_.keys():
                Utility_[D]={O:Utility[O][D]}
            else:
                Utility_[D][O]=Utility[O][D]

    for D in Utility_.keys():

         model += pulp.lpSum([X[(O, D)] for O in Utility_[D].keys()]) <=1

    model.solve()

    result={}

    for var in X:

        var_value = X[var].varValue
        
        if var_value !=0:
            
            result[var[0]]=var[1]
    

    return result   

'''Matching algorithm'''

def One2Many_Matching(Utility,Order_quantity,Dropoff_Drivers):

    '''Define the problem'''

    model = pulp.LpProblem("Ride_Matching_Problems", pulp.LpMaximize)

    '''Construct our decision variable lists'''

    X = pulp.LpVariable.dicts("X",((D,G) for D in Utility.keys() for G in Utility[D].keys()),lowBound=0,upBound=1,cat='Integer')

    '''Objective Function'''

    model += (pulp.lpSum([Utility[D][G] * X[(D, G)] for D in Utility.keys() for G in Utility[D].keys()]))
    
    '''Each Driver '''

    for D in Utility.keys():

        model += pulp.lpSum([X[(D, G)] for G in Utility[D].keys()]) <= 1

    '''Each Hexagon'''
    
    Utility_={}
    
    for D in Utility.keys():
        for G in Utility[D].keys():
            if G not in Utility_.keys():
                Utility_[G]={D:Utility[D][G]}
            else:
                Utility_[G][D]=Utility[D][G]

    for G in Utility_.keys():

        model += pulp.lpSum([X[(D, G)] for D in Utility_[G].keys()]) <= 10*Order_quantity[G]

    model.solve()

    result={}

    for var in X:

        var_value = X[var].varValue
        
        if var_value !=0:
            
            result[var[0]]=var[1]

    return result

# %% [markdown]
# ## 05 Basic parameters

# %%
'''Systemic paths'''

Load_path='./NYC_Network/'



'''Parameters'''

Start_step=2520 # Start stamp 

End_step=3600 # End stamp 

# Max_waiting=12 # Waiting Patience

radius=2000 # Matching Radius

grid_radius=int(np.ceil(radius/350.0)) # Matching Radius in hexagonal level

speed=20000/360 # Speed, meters per ten seconds 

resolution = 9

ini_step=2520



'''Network data'''

'''Grid-related data'''

Grid_list=np.load(os.path.join(Load_path,'Grids.npy'),allow_pickle=True)

Grid_Point=np.load(os.path.join(Load_path,'Grid_Point.npy'),allow_pickle=True).item()

'''Point-related data'''

Points_list=np.load(os.path.join(Load_path,'Points_list.npy'),allow_pickle=True)

Link_Point=np.load(os.path.join(Load_path,'Link_Point.npy'),allow_pickle=True).item()

Point_coordinate=np.load(os.path.join(Load_path,'Point_coordinate.npy'),allow_pickle=True).item()

Point_Grid=np.load(os.path.join(Load_path,'Point_Grid.npy'),allow_pickle=True).item()


'''Initialize classes'''

Hex=Hexagon(resolution)


'''date'''

day='2020-12-01'

'''Wage'''

Commission_rate={'A':0.20,'B':0.25}

'''Drivers utility ''' 


beta1=0.15

decline_utility=5


'''Drivers utility'''

beta2=0.2

# %%
'''(1) Load Order data'''

Order_df=pd.read_csv(os.path.join('Order_df_'+str(day)+'.csv'))

Order_df=Order_df.drop(columns=['Unnamed: 0'])


Order_df['Travel_duration']=Order_df.apply(lambda x:int(x['Travel_time']/6),axis=1)

Order_df['Pickup_Point']=Order_df.apply(lambda x:[x['Pickup_Latitude'],x['Pickup_Longitude']],axis=1)

Order_df['Dropoff_Point']=Order_df.apply(lambda x:[x['Dropoff_Latitude'],x['Dropoff_Longitude']],axis=1)

Order_df['Platform']='Null'

'''(2) Load Driver data'''

Driver_df=pd.read_csv(os.path.join('Driver_df_'+str(day)+'.csv'))

Driver_df=Driver_df.drop(columns=['Unnamed: 0'])

Driver_df['Point']=Driver_df.apply(lambda x:[float(p) for p in x['Point'].replace('[','').replace(']','').split(',')],axis=1)

Driver_df['Reposition_Point']=Driver_df.apply(lambda x:x['Point'],axis=1)


'''(3) Simulator'''

Record= pd.DataFrame([],columns=['step','Driver_selelction_A', 'Driver_selelction_B',\
                                 'Passenger_selection_A','Passenger_selection_B',\
                                 'Instant_match','Instant_cancel','Idle_vehicles',\
                                 'Cumulative_match', 'Cumulative_cancel'],dtype=object)


for step in range(Start_step,End_step,1):
    
    print('*'*50)
    
    print('Current step ',step)
    
    '''(3-1) collect unserved orders and arriving orders'''

    Order_batch=Order_df[(Order_df['Arrive_step']<=step)&(Order_df['Driver_id']=='Waiting')]

    Order_info={}

    for idx,row in Order_batch.iterrows():
        
        Order_info[row['Order_id']]={}
        
        Order_info[row['Order_id']]['Pickup_Point']=row['Pickup_Point']
        
        Order_info[row['Order_id']]['Pickup_Grid']=row['Pickup_Grid']
        
        Order_info[row['Order_id']]['Dropoff_Point']=row['Dropoff_Point']
        
        Order_info[row['Order_id']]['Dropoff_Grid']=row['Dropoff_Grid']
        
        Order_info[row['Order_id']]['Travel_time']=row['Travel_time']
        
        Order_info[row['Order_id']]['Travel_duration']=row['Travel_duration']

        Order_info[row['Order_id']]['Match_Grids']=Hex.Get_Neigh(row['Pickup_Grid'],grid_radius)

        Order_info[row['Order_id']]['Matching_patience']=row['Matching_patience']

        Order_info[row['Order_id']]['Fare_A']=row['Fare_A']
        
        Order_info[row['Order_id']]['Fare_B']=row['Fare_B']

    Operation_Grids=Hex.Compact_lists([x['Match_Grids'] for x in Order_info.values()])
    
    
    '''(3-2) collect Idle drivers'''
    
    Driver_batch=Driver_df[(Driver_df['Step']==step)&(Driver_df['Order_id']=='Idle')&(Driver_df['Grid'].isin(Operation_Grids))]

    Driver_info={}

    Grid_Drivers={}

    for idx,row in Driver_batch.iterrows():
        
        Driver_info[row['Driver_id']]={}

        Driver_info[row['Driver_id']]['Point']=row['Point']
        
        Driver_info[row['Driver_id']]['Grid']=row['Grid']
        
        if row['Grid'] in Grid_Drivers.keys():

            Grid_Drivers[row['Grid']].append(row['Driver_id'])

        else:

            Grid_Drivers[row['Grid']]=[row['Driver_id']]
            
    Idle_drivers=list(Driver_df.loc[(Driver_df['Step']==step)&(Driver_df['Order_id']=='Idle'),'Driver_id'])
    
            
    '''(3-3) Order Dispatching'''
    
    Matching_result={}
    
    Pickup_time={order_id:{} for order_id in Order_info.keys()}

    
    Profit_A={order_id:{} for order_id in Order_info.keys()}
    
    Profit_B={order_id:{} for order_id in Order_info.keys()}

    for order_id in Order_info.keys():
        
        origin=Order_info[order_id]['Pickup_Point']

        Fare_A=Order_info[order_id]['Fare_A']
        
        Fare_B=Order_info[order_id]['Fare_B']
        
        Candidate_grids=Order_info[order_id]['Match_Grids']

        for grid in Candidate_grids:

            '''Existing driver?'''
            
            if grid in Grid_Drivers.keys():

                for driver_id in Grid_Drivers[grid]:

                        Profit_A[order_id][driver_id]=Commission_rate['A']*Fare_A
                        
                        Profit_B[order_id][driver_id]=Commission_rate['B']*Fare_B
                        
                        loc=Driver_info[driver_id]['Point']

                        pickup_dis=Get_distance(origin,loc)
                        
                        Pickup_time[order_id][driver_id]=int(Get_travel_time(pickup_dis,speed))
                        
    Matching_result['A']=One2One_Matching(Profit_A)
    
    Matching_result['B']=One2One_Matching(Profit_B)
    
    
    
    
    
    '''(3-4) Drivers make a selection'''
    
    Drivers_Utility={}
    
    for platform,results in Matching_result.items():
        
        for order_id,driver_id in results.items():
            
            if driver_id not in Drivers_Utility.keys():

                Drivers_Utility[driver_id]={}
                
                Drivers_Utility[driver_id][platform+'_'+order_id]=Order_info[order_id]['Fare_'+platform]*(1-Commission_rate[platform])-beta1*Order_info[order_id]['Travel_duration']
                
            else:
                
                Drivers_Utility[driver_id][platform+'_'+order_id]=Order_info[order_id]['Fare_'+platform]*(1-Commission_rate[platform])-beta1*Order_info[order_id]['Travel_duration']
                
    for driver_id in Drivers_Utility.keys():
                
        Drivers_Utility[driver_id]['Decline']=decline_utility
        
        
    Drivers_Selection={}
    
    Drivers_Selection_Count={'A':0,'B':0}
    
    for driver_id in Drivers_Utility.keys():
        
        selection=max(Drivers_Utility[driver_id], key=Drivers_Utility[driver_id].get)
        
        platform=selection.split('_')[0]
        
        Drivers_Selection[driver_id]=selection
        
        if platform!='Decline':
        
            Drivers_Selection_Count[platform]+=1
    
    '''(3-5) Passengers make a selection'''
    
    Passengers_Utility={}
    
    for platform,results in Matching_result.items():
        
        for order_id,driver_id in results.items():
            
            if order_id not in Passengers_Utility.keys():

                Passengers_Utility[order_id]={}
                
                Passengers_Utility[order_id][driver_id+'_'+platform]=Order_info[order_id]['Fare_'+platform]-beta2*Order_info[order_id]['Travel_duration']
                
            else:
                
                Passengers_Utility[order_id][driver_id+'_'+platform]=Order_info[order_id]['Fare_'+platform]-beta2*Order_info[order_id]['Travel_duration']
            
        
        
    Passengers_Selection={}
    
    Passengers_Selection_Count={'A':0,'B':0}
    
    for order_id in Passengers_Utility.keys():
        
        selection=min(Passengers_Utility[order_id], key=Passengers_Utility[order_id].get)
        
        platform=selection.split('_')[-1]
        
        Passengers_Selection[order_id]=selection
        
        Passengers_Selection_Count[platform]+=1
    
        
    '''(3-6) Consensus'''
    
    Matching_result={}
    
    Matching_platform={}
    
    Driver_consensus=[]
    
    Order_consensus=[]
    
    for driver_id,value in Drivers_Selection.items():
        
        Driver_consensus.append(driver_id+'_'+value)
        
    for order_id,value in Passengers_Selection.items():
        
        Order_consensus.append(value+'_'+order_id)
        
    Consensus=[pair for pair in Driver_consensus if pair in Order_consensus]
    
    for pair in Consensus:
        
        order_id=pair.split('_')[2]
        
        driver_id=pair.split('_')[0]
        
        platform=pair.split('_')[1]
        
        Matching_result[order_id]=driver_id
        
        Matching_platform[order_id]=platform
        


    
    
    '''(3-7) Assignment'''

    
    for order_id,driver_id in Matching_result.items():
        
        Added_item={}
        
        Pickup_step=step+Pickup_time[order_id][driver_id]
        
        Dropoff_step=Pickup_step+Order_info[order_id]['Travel_time']

        Order_df.loc[(Order_df['Order_id']==order_id),'Response_step']=step

        Order_df.loc[(Order_df['Order_id']==order_id),'Pickup_step']=Pickup_step

        Order_df.loc[(Order_df['Order_id']==order_id),'Driver_id']=driver_id

        Order_df.loc[(Order_df['Order_id']==order_id),'Platform']=Matching_platform[order_id]

        '''Matched driver'''

        Driver_df.loc[(Driver_df['Step']==step)&(Driver_df['Driver_id']==driver_id),'Order_id']=order_id

        Added_item['Driver_id']=driver_id

        Added_item['Order_id']='Idle'

        Added_item['Step']=Dropoff_step

        Added_item['Point']=Order_info[order_id]['Dropoff_Point']

        Added_item['Grid']=Order_info[order_id]['Dropoff_Grid']

        Added_item['Reposition_Point']=Order_info[order_id]['Dropoff_Point']

        Added_item['Reposition_Grid']=Order_info[order_id]['Dropoff_Grid']
        
        Driver_df=Driver_df.append(Added_item, ignore_index=True)


            
    '''Canceled Orders'''
        
    Unmatched_orders=[O for O in Order_info.keys() if O not in Matching_result.keys()]
    
    cancellation=0

    if len(Unmatched_orders)!=0:
        
        cancellation=Order_df.loc[((step-Order_df['Arrive_step'])>Order_df['Matching_patience'])&(Order_df['Order_id'].isin(Unmatched_orders))].shape[0]

        Order_df.loc[((step-Order_df['Arrive_step'])>Order_df['Matching_patience'])&(Order_df['Order_id'].isin(Unmatched_orders)),'Driver_id']='Canceled'

        
    '''(3-8) Repositioning'''
    
    Repositioned_drivers=copy.deepcopy(Driver_df.loc[(Driver_df['Step']==step)&(Driver_df['Order_id']=='Idle')])
    
    Repositioned_drivers['Next_Step']=step+1

    Repositioned_drivers=Repositioned_drivers[['Driver_id','Order_id','Next_Step','Point','Grid','Reposition_Point','Reposition_Grid']]

    Repositioned_drivers=Repositioned_drivers.rename(columns={'Next_Step':'Step'})

    Repositioned_drivers=Repositioned_drivers[['Driver_id','Order_id','Step','Point','Grid','Reposition_Point','Reposition_Grid']]
    
    Driver_df=pd.concat([Driver_df,Repositioned_drivers],ignore_index=True)
    
    
    '''(3-8) Statistics'''
    
    Instant_cancel=cancellation
    
    Instant_match=len(Matching_result)
    
    Culmulative_cancel=Order_df.loc[(Order_df['Driver_id']=='Canceled')].shape[0]
        
    Culmulative_match=Order_df.loc[(Order_df['Driver_id']!='Waiting')&(Order_df['Driver_id']!='Canceled')].shape[0]
    
    
    record={}
    
    record['step']=step
    
    record['Driver_selelction_A']=Drivers_Selection_Count['A']
    
    record['Driver_selelction_B']=Drivers_Selection_Count['B']
    
    record['Passenger_selection_A']=Passengers_Selection_Count['A']
    
    record['Passenger_selection_B']=Passengers_Selection_Count['B']
    
    record['Instant_match']=Instant_match
    
    record['Instant_cancel']=Instant_cancel
    
    record['Idle_vehicles']=Repositioned_drivers.loc[Repositioned_drivers['Point']==Repositioned_drivers['Reposition_Point']].shape[0]

    record['Cumulative_match']=Culmulative_match
    
    record['Cumulative_cancel']=Culmulative_cancel
    
    Record=Record.append(record, ignore_index=True)
    

    print('\n'*2)
    
    
    print('Instant match: ',Instant_match)
    
    print('Instant cancel: ',Instant_cancel)
    
    print('Cumulative match: ',Culmulative_match)
    
    print('Cumulative cancel: ',Culmulative_cancel)
# Out:
# **************************************************
# Current step  2520
#
#
#
# Instant match:  0
# Instant cancel:  0
# Cumulative match:  0
# Cumulative cancel:  0
# **************************************************
# Current step  2521
#
#
#
# Instant match:  0
# Instant cancel:  0
# Cumulative match:  0
# Cumulative cancel:  0
# **************************************************
# Current step  2522
#
#
#
# Instant match:  0
# Instant cancel:  0
# Cumulative match:  0
# Cumulative cancel:  0
# **************************************************
# Current step  2523
#
#
#
# Instant match:  0
# Instant cancel:  0
# Cumulative match:  0
# Cumulative cancel:  0
# **************************************************
# Current step  2524
#
#
#
# Instant match:  0
# Instant cancel:  0
# Cumulative match:  0
# Cumulative cancel:  0
# **************************************************
# Current step  2525
#
#
#
# Instant match:  0
# Instant cancel:  1
# Cumulative match:  0
# Cumulative cancel:  1
# **************************************************
# Current step  2526
#
#
#
# Instant match:  0
# Instant cancel:  3
# Cumulative match:  0
# Cumulative cancel:  4
# **************************************************
# Current step  2527
#
#
#
# Instant match:  0
# Instant cancel:  1
# Cumulative match:  0
# Cumulative cancel:  5
# **************************************************
# Current step  2528
#
#
#
# Instant match:  0
# Instant cancel:  6
# Cumulative match:  0
# Cumulative cancel:  11
# **************************************************
# Current step  2529
#
#
#
# Instant match:  0
# Instant cancel:  0
# Cumulative match:  0
# Cumulative cancel:  11
# **************************************************
# Current step  2530
#
#
#
# Instant match:  0
# Instant cancel:  3
# Cumulative match:  0
# Cumulative cancel:  14
# **************************************************
# Current step  2531
#
#
#
# Instant match:  0
# Instant cancel:  5
# Cumulative match:  0
# Cumulative cancel:  19
# **************************************************
# Current step  2532
#
#
#
# Instant match:  0
# Instant cancel:  3
# Cumulative match:  0
# Cumulative cancel:  22
# **************************************************
# Current step  2533
#
#
#
# Instant match:  1
# Instant cancel:  4
# Cumulative match:  1
# Cumulative cancel:  26
# **************************************************
# Current step  2534
#
#
#
# Instant match:  1
# Instant cancel:  2
# Cumulative match:  2
# Cumulative cancel:  28
# **************************************************
# Current step  2535
#
#
#
# Instant match:  0
# Instant cancel:  2
# Cumulative match:  2
# Cumulative cancel:  30
# **************************************************
# Current step  2536
#
#
#
# Instant match:  0
# Instant cancel:  6
# Cumulative match:  2
# Cumulative cancel:  36
# **************************************************
# Current step  2537
#
#
#
# Instant match:  0
# Instant cancel:  2
# Cumulative match:  2
# Cumulative cancel:  38
# **************************************************
# Current step  2538
#
#
#
# Instant match:  0
# Instant cancel:  4
# Cumulative match:  2
# Cumulative cancel:  42
# **************************************************
# Current step  2539
#
#
#
# Instant match:  1
# Instant cancel:  5
# Cumulative match:  3
# Cumulative cancel:  47
# **************************************************
# Current step  2540
#
#
#
# Instant match:  0
# Instant cancel:  7
# Cumulative match:  3
# Cumulative cancel:  54
# **************************************************
# Current step  2541
#
#
#
# Instant match:  1
# Instant cancel:  2
# Cumulative match:  4
# Cumulative cancel:  56
# **************************************************
# Current step  2542
#
#
#
# Instant match:  0
# Instant cancel:  3
# Cumulative match:  4
# Cumulative cancel:  59
# **************************************************
# Current step  2543
#
#
#
# Instant match:  0
# Instant cancel:  1
# Cumulative match:  4
# Cumulative cancel:  60
# **************************************************
# Current step  2544
#
#
#
# Instant match:  2
# Instant cancel:  8
# Cumulative match:  6
# Cumulative cancel:  68
# **************************************************
# Current step  2545
#
#
#
# Instant match:  1
# Instant cancel:  6
# Cumulative match:  7
# Cumulative cancel:  74
# **************************************************
# Current step  2546
#
#
#
# Instant match:  0
# Instant cancel:  1
# Cumulative match:  7
# Cumulative cancel:  75
# **************************************************
# Current step  2547
#
#
#
# Instant match:  0
# Instant cancel:  4
# Cumulative match:  7
# Cumulative cancel:  79
# **************************************************
# Current step  2548
#
#
#
# Instant match:  0
# Instant cancel:  1
# Cumulative match:  7
# Cumulative cancel:  80
# **************************************************
# Current step  2549
#
#
#
# Instant match:  0
# Instant cancel:  0
# Cumulative match:  7
# Cumulative cancel:  80
# **************************************************
# Current step  2550
#
#
#
# Instant match:  1
# Instant cancel:  3
# Cumulative match:  8
# Cumulative cancel:  83
# **************************************************
# Current step  2551
#
#
#
# Instant match:  0
# Instant cancel:  4
# Cumulative match:  8
# Cumulative cancel:  87
# **************************************************
# Current step  2552
#
#
#
# Instant match:  0
# Instant cancel:  1
# Cumulative match:  8
# Cumulative cancel:  88
# **************************************************
# Current step  2553
#
#
#
# Instant match:  1
# Instant cancel:  4
# Cumulative match:  9
# Cumulative cancel:  92
# **************************************************
# Current step  2554
#
#
#
# Instant match:  0
# Instant cancel:  0
# Cumulative match:  9
# Cumulative cancel:  92
# **************************************************
# Current step  2555
#
#
#
# Instant match:  0
# Instant cancel:  3
# Cumulative match:  9
# Cumulative cancel:  95
# **************************************************
# Current step  2556
#
#
#
# Instant match:  0
# Instant cancel:  4
# Cumulative match:  9
# Cumulative cancel:  99
# **************************************************
# Current step  2557
#
#
#
# Instant match:  0
# Instant cancel:  1
# Cumulative match:  9
# Cumulative cancel:  100
# **************************************************
# Current step  2558
#
#
#
# Instant match:  0
# Instant cancel:  2
# Cumulative match:  9
# Cumulative cancel:  102
# **************************************************
# Current step  2559
#
#
#
# Instant match:  1
# Instant cancel:  3
# Cumulative match:  10
# Cumulative cancel:  105
# **************************************************
# Current step  2560
#
#
#
# Instant match:  1
# Instant cancel:  4
# Cumulative match:  11
# Cumulative cancel:  109
# **************************************************
# Current step  2561
#
#
#
# Instant match:  0
# Instant cancel:  4
# Cumulative match:  11
# Cumulative cancel:  113
# **************************************************
# Current step  2562
#
#
#
# Instant match:  2
# Instant cancel:  2
# Cumulative match:  13
# Cumulative cancel:  115
# **************************************************
# Current step  2563
#
#
#
# Instant match:  0
# Instant cancel:  2
# Cumulative match:  13
# Cumulative cancel:  117
# **************************************************
# Current step  2564
#
#
#
# Instant match:  0
# Instant cancel:  5
# Cumulative match:  13
# Cumulative cancel:  122
# **************************************************
# Current step  2565
#
#
#
# Instant match:  0
# Instant cancel:  3
# Cumulative match:  13
# Cumulative cancel:  125
# **************************************************
# Current step  2566
#
#
#
# Instant match:  0
# Instant cancel:  4
# Cumulative match:  13
# Cumulative cancel:  129
# **************************************************
# Current step  2567
#
#
#
# Instant match:  0
# Instant cancel:  2
# Cumulative match:  13
# Cumulative cancel:  131
# **************************************************
# Current step  2568
#
#
#
# Instant match:  2
# Instant cancel:  6
# Cumulative match:  15
# Cumulative cancel:  137
# **************************************************
# Current step  2569
#
#
#
# Instant match:  0
# Instant cancel:  7
# Cumulative match:  15
# Cumulative cancel:  144
# **************************************************
# Current step  2570
#
#
#
# Instant match:  1
# Instant cancel:  6
# Cumulative match:  16
# Cumulative cancel:  150
# **************************************************
# Current step  2571
# Exception ignored in: <function BaseGeometry.__del__ at 0x7fd3188a7ee0>
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.8/site-packages/shapely/geometry/base.py", line 209, in __del__
#     self._empty(val=None)
#   File "/opt/anaconda3/lib/python3.8/site-packages/shapely/geometry/base.py", line 199, in _empty
#     self._is_empty = True
#   File "/opt/anaconda3/lib/python3.8/site-packages/shapely/geometry/base.py", line 250, in __setattr__
#     super().__setattr__(name, value)
# KeyboardInterrupt:
# Instant match:  0
# Instant cancel:  3
# Cumulative match:  16
# Cumulative cancel:  153
# **************************************************
# Current step  2572
#
#
#
# Instant match:  0
# Instant cancel:  3
# Cumulative match:  16
# Cumulative cancel:  156
# **************************************************
# Current step  2573
#
#
#
# Instant match:  0
# Instant cancel:  4
# Cumulative match:  16
# Cumulative cancel:  160
# **************************************************
# Current step  2574
#
#
#
# Instant match:  3
# Instant cancel:  3
# Cumulative match:  19
# Cumulative cancel:  163
# **************************************************
# Current step  2575
#
#
#
# Instant match:  0
# Instant cancel:  2
# Cumulative match:  19
# Cumulative cancel:  165
# **************************************************
# Current step  2576
#
#
#
# Instant match:  1
# Instant cancel:  6
# Cumulative match:  20
# Cumulative cancel:  171
# **************************************************
# Current step  2577
#
#
#
# Instant match:  1
# Instant cancel:  2
# Cumulative match:  21
# Cumulative cancel:  173
# **************************************************
# Current step  2578
#
#
#
# Instant match:  1
# Instant cancel:  2
# Cumulative match:  22
# Cumulative cancel:  175
# **************************************************
# Current step  2579
#
#
#
# Instant match:  0
# Instant cancel:  2
# Cumulative match:  22
# Cumulative cancel:  177
# **************************************************
# Current step  2580
#
#
#
# Instant match:  1
# Instant cancel:  3
# Cumulative match:  23
# Cumulative cancel:  180
# **************************************************
# Current step  2581
#
#
#
# Instant match:  1
# Instant cancel:  6
# Cumulative match:  24
# Cumulative cancel:  186
# **************************************************
# Current step  2582
#
#
#
# Instant match:  1
# Instant cancel:  3
# Cumulative match:  25
# Cumulative cancel:  189
# **************************************************
# Current step  2583
#
#
#
# Instant match:  3
# Instant cancel:  8
# Cumulative match:  28
# Cumulative cancel:  197
# **************************************************
# Current step  2584
#
#
#
# Instant match:  0
# Instant cancel:  2
# Cumulative match:  28
# Cumulative cancel:  199
# **************************************************
# Current step  2585
#
#
#
# Instant match:  0
# Instant cancel:  6
# Cumulative match:  28
# Cumulative cancel:  205
# **************************************************
# Current step  2586
#
#
#
# Instant match:  0
# Instant cancel:  4
# Cumulative match:  28
# Cumulative cancel:  209
# **************************************************
# Current step  2587
#
#
#
# Instant match:  0
# Instant cancel:  1
# Cumulative match:  28
# Cumulative cancel:  210
# **************************************************
# Current step  2588
#
#
#
# Instant match:  0
# Instant cancel:  4
# Cumulative match:  28
# Cumulative cancel:  214
# **************************************************
# Current step  2589
#
#
#
# Instant match:  0
# Instant cancel:  6
# Cumulative match:  28
# Cumulative cancel:  220
# **************************************************
# Current step  2590
#
#
#
# Instant match:  0
# Instant cancel:  2
# Cumulative match:  28
# Cumulative cancel:  222
# **************************************************
# Current step  2591
#
#
#
# Instant match:  0
# Instant cancel:  4
# Cumulative match:  28
# Cumulative cancel:  226
# **************************************************
# Current step  2592
#
#
#
# Instant match:  0
# Instant cancel:  4
# Cumulative match:  28
# Cumulative cancel:  230
# **************************************************
# Current step  2593
#
#
#
# Instant match:  1
# Instant cancel:  3
# Cumulative match:  29
# Cumulative cancel:  233
# **************************************************
# Current step  2594
#
#
#
# Instant match:  1
# Instant cancel:  3
# Cumulative match:  30
# Cumulative cancel:  236
# **************************************************
# Current step  2595
#
#
#
# Instant match:  1
# Instant cancel:  6
# Cumulative match:  31
# Cumulative cancel:  242
# **************************************************
# Current step  2596
#
#
#
# Instant match:  0
# Instant cancel:  4
# Cumulative match:  31
# Cumulative cancel:  246
# **************************************************
# Current step  2597
#
#
#
# Instant match:  0
# Instant cancel:  2
# Cumulative match:  31
# Cumulative cancel:  248
# **************************************************
# Current step  2598
#
#
#
# Instant match:  0
# Instant cancel:  2
# Cumulative match:  31
# Cumulative cancel:  250
# **************************************************
# Current step  2599
#
#
#
# Instant match:  0
# Instant cancel:  7
# Cumulative match:  31
# Cumulative cancel:  257
# **************************************************
# Current step  2600
#
#
#
# Instant match:  0
# Instant cancel:  1
# Cumulative match:  31
# Cumulative cancel:  258
# **************************************************
# Current step  2601
#
#
#
# Instant match:  0
# Instant cancel:  2
# Cumulative match:  31
# Cumulative cancel:  260
# **************************************************
# Current step  2602
#
#
#
# Instant match:  0
# Instant cancel:  0
# Cumulative match:  31
# Cumulative cancel:  260
# **************************************************
# Current step  2603
#
#
#
# Instant match:  0
# Instant cancel:  2
# Cumulative match:  31
# Cumulative cancel:  262
# **************************************************
# Current step  2604
#
#
#
# Instant match:  0
# Instant cancel:  4
# Cumulative match:  31
# Cumulative cancel:  266
# **************************************************
# Current step  2605
#
#
#
# Instant match:  0
# Instant cancel:  3
# Cumulative match:  31
# Cumulative cancel:  269
# **************************************************
# Current step  2606
#
#
#
# Instant match:  0
# Instant cancel:  6
# Cumulative match:  31
# Cumulative cancel:  275
# **************************************************
# Current step  2607
#
#
#
# Instant match:  0
# Instant cancel:  3
# Cumulative match:  31
# Cumulative cancel:  278
# **************************************************
# Current step  2608
#
#
#
# Instant match:  0
# Instant cancel:  2
# Cumulative match:  31
# Cumulative cancel:  280
# **************************************************
# Current step  2609
#
#
#
# Instant match:  0
# Instant cancel:  3
# Cumulative match:  31
# Cumulative cancel:  283
# **************************************************
# Current step  2610
#
#
#
# Instant match:  0
# Instant cancel:  4
# Cumulative match:  31
# Cumulative cancel:  287
# **************************************************
# Current step  2611
#
#
#
# Instant match:  0
# Instant cancel:  3
# Cumulative match:  31
# Cumulative cancel:  290
# **************************************************
# Current step  2612
#
#
#
# Instant match:  0
# Instant cancel:  5
# Cumulative match:  31
# Cumulative cancel:  295
# **************************************************
# Current step  2613
#
#
#
# Instant match:  0
# Instant cancel:  3
# Cumulative match:  31
# Cumulative cancel:  298
# **************************************************
# Current step  2614
#
#
#
# Instant match:  0
# Instant cancel:  3
# Cumulative match:  31
# Cumulative cancel:  301
# **************************************************
# Current step  2615
#
#
#
# Instant match:  0
# Instant cancel:  5
# Cumulative match:  31
# Cumulative cancel:  306
# **************************************************
# Current step  2616
#
#
#
# Instant match:  1
# Instant cancel:  3
# Cumulative match:  32
# Cumulative cancel:  309
# **************************************************
# Current step  2617
#
#
#
# Instant match:  0
# Instant cancel:  4
# Cumulative match:  32
# Cumulative cancel:  313
# **************************************************
# Current step  2618
#
#
#
# Instant match:  0
# Instant cancel:  2
# Cumulative match:  32
# Cumulative cancel:  315
# **************************************************
# Current step  2619
#
#
#
# Instant match:  1
# Instant cancel:  3
# Cumulative match:  33
# Cumulative cancel:  318
# **************************************************
# Current step  2620
#
#
#
# Instant match:  0
# Instant cancel:  1
# Cumulative match:  33
# Cumulative cancel:  319
# **************************************************
# Current step  2621
#
#
#
# Instant match:  1
# Instant cancel:  1
# Cumulative match:  34
# Cumulative cancel:  320
# **************************************************
# Current step  2622
#
#
#
# Instant match:  0
# Instant cancel:  4
# Cumulative match:  34
# Cumulative cancel:  324
# **************************************************
# Current step  2623
#
#
#
# Instant match:  0
# Instant cancel:  6
# Cumulative match:  34
# Cumulative cancel:  330
# **************************************************
# Current step  2624
#
#
#
# Instant match:  0
# Instant cancel:  4
# Cumulative match:  34
# Cumulative cancel:  334
# **************************************************
# Current step  2625
# Instant match:  0
# Instant cancel:  6
# Cumulative match:  34
# Cumulative cancel:  340
# **************************************************
# Current step  2626
#
#
#
# Instant match:  0
# Instant cancel:  2
# Cumulative match:  34
# Cumulative cancel:  342
# **************************************************
# Current step  2627
#
#
#
# Instant match:  0
# Instant cancel:  3
# Cumulative match:  34
# Cumulative cancel:  345
# **************************************************
# Current step  2628
#
#
#
# Instant match:  1
# Instant cancel:  5
# Cumulative match:  35
# Cumulative cancel:  350
# **************************************************
# Current step  2629
#
#
#
# Instant match:  0
# Instant cancel:  4
# Cumulative match:  35
# Cumulative cancel:  354
# **************************************************
# Current step  2630
#
#
#
# Instant match:  0
# Instant cancel:  3
# Cumulative match:  35
# Cumulative cancel:  357
# **************************************************
# Current step  2631
#
#
#
# Instant match:  0
# Instant cancel:  6
# Cumulative match:  35
# Cumulative cancel:  363
# **************************************************
# Current step  2632
#
#
#
# Instant match:  0
# Instant cancel:  2
# Cumulative match:  35
# Cumulative cancel:  365
# **************************************************
# Current step  2633
#
#
#
# Instant match:  0
# Instant cancel:  6
# Cumulative match:  35
# Cumulative cancel:  371
# **************************************************
# Current step  2634
#
#
#
# Instant match:  0
# Instant cancel:  2
# Cumulative match:  35
# Cumulative cancel:  373
# **************************************************
# Current step  2635
#
#
#
# Instant match:  1
# Instant cancel:  2
# Cumulative match:  36
# Cumulative cancel:  375
# **************************************************
# Current step  2636
#
#
#
# Instant match:  0
# Instant cancel:  3
# Cumulative match:  36
# Cumulative cancel:  378
# **************************************************
# Current step  2637
#
#
#
# Instant match:  1
# Instant cancel:  1
# Cumulative match:  37
# Cumulative cancel:  379
# **************************************************
# Current step  2638
#
#
#
# Instant match:  3
# Instant cancel:  7
# Cumulative match:  40
# Cumulative cancel:  386
# **************************************************
# Current step  2639
#
#
#
# Instant match:  0
# Instant cancel:  3
# Cumulative match:  40
# Cumulative cancel:  389
# **************************************************
# Current step  2640
#
#
#
# Instant match:  0
# Instant cancel:  7
# Cumulative match:  40
# Cumulative cancel:  396
# **************************************************
# Current step  2641
#
#
#
# Instant match:  0
# Instant cancel:  9
# Cumulative match:  40
# Cumulative cancel:  405
# **************************************************
# Current step  2642
#
#
#
# Instant match:  0
# Instant cancel:  4
# Cumulative match:  40
# Cumulative cancel:  409
# **************************************************
# Current step  2643
#
#
#
# Instant match:  1
# Instant cancel:  1
# Cumulative match:  41
# Cumulative cancel:  410
# **************************************************
# Current step  2644
#
#
#
# Instant match:  0
# Instant cancel:  1
# Cumulative match:  41
# Cumulative cancel:  411
# **************************************************
# Current step  2645
#
#
#
# Instant match:  0
# Instant cancel:  4
# Cumulative match:  41
# Cumulative cancel:  415
# **************************************************
# Current step  2646
#
#
#
# Instant match:  0
# Instant cancel:  5
# Cumulative match:  41
# Cumulative cancel:  420
# **************************************************
# Current step  2647
#
#
#
# Instant match:  0
# Instant cancel:  9
# Cumulative match:  41
# Cumulative cancel:  429
# **************************************************
# Current step  2648
#
#
#
# Instant match:  0
# Instant cancel:  1
# Cumulative match:  41
# Cumulative cancel:  430
# **************************************************
# Current step  2649
#
#
#
# Instant match:  0
# Instant cancel:  3
# Cumulative match:  41
# Cumulative cancel:  433
# **************************************************
# Current step  2650
#
#
#
# Instant match:  0
# Instant cancel:  5
# Cumulative match:  41
# Cumulative cancel:  438
# **************************************************
# Current step  2651
#
#
#
# Instant match:  1
# Instant cancel:  8
# Cumulative match:  42
# Cumulative cancel:  446
# **************************************************
# Current step  2652
#
#
#
# Instant match:  0
# Instant cancel:  4
# Cumulative match:  42
# Cumulative cancel:  450
# **************************************************
# Current step  2653
#
#
#
# Instant match:  0
# Instant cancel:  3
# Cumulative match:  42
# Cumulative cancel:  453
# **************************************************
# Current step  2654
#
#
#
# Instant match:  0
# Instant cancel:  3
# Cumulative match:  42
# Cumulative cancel:  456
# **************************************************
# Current step  2655
#
#
#
# Instant match:  0
# Instant cancel:  2
# Cumulative match:  42
# Cumulative cancel:  458
# **************************************************
# Current step  2656
#
#
#
# Instant match:  0
# Instant cancel:  6
# Cumulative match:  42
# Cumulative cancel:  464
# **************************************************
# Current step  2657
#
#
#
# Instant match:  0
# Instant cancel:  4
# Cumulative match:  42
# Cumulative cancel:  468
# **************************************************
# Current step  2658
#
#
#
# Instant match:  1
# Instant cancel:  5
# Cumulative match:  43
# Cumulative cancel:  473
# **************************************************
# Current step  2659
#
#
#
# Instant match:  1
# Instant cancel:  2
# Cumulative match:  44
# Cumulative cancel:  475
# **************************************************
# Current step  2660
#
#
#
# Instant match:  0
# Instant cancel:  5
# Cumulative match:  44
# Cumulative cancel:  480
# **************************************************
# Current step  2661
#
#
#
# Instant match:  0
# Instant cancel:  3
# Cumulative match:  44
# Cumulative cancel:  483
# **************************************************
# Current step  2662
#
#
#
# Instant match:  1
# Instant cancel:  5
# Cumulative match:  45
# Cumulative cancel:  488
# **************************************************
# Current step  2663
#
#
#
# Instant match:  2
# Instant cancel:  5
# Cumulative match:  47
# Cumulative cancel:  493
# **************************************************
# Current step  2664
#
#
#
# Instant match:  1
# Instant cancel:  1
# Cumulative match:  48
# Cumulative cancel:  494
# **************************************************
# Current step  2665
#
#
#
# Instant match:  0
# Instant cancel:  4
# Cumulative match:  48
# Cumulative cancel:  498
# **************************************************
# Current step  2666
#
#
#
# Instant match:  1
# Instant cancel:  5
# Cumulative match:  49
# Cumulative cancel:  503
# **************************************************
# Current step  2667
#
#
#
# Instant match:  0
# Instant cancel:  2
# Cumulative match:  49
# Cumulative cancel:  505
# **************************************************
# Current step  2668
#
#
#
# Instant match:  0
# Instant cancel:  0
# Cumulative match:  49
# Cumulative cancel:  505
# **************************************************
# Current step  2669
#
#
#
# Instant match:  1
# Instant cancel:  6
# Cumulative match:  50
# Cumulative cancel:  511
# **************************************************
# Current step  2670
#
#
#
# Instant match:  0
# Instant cancel:  4
# Cumulative match:  50
# Cumulative cancel:  515
# **************************************************
# Current step  2671
#
#
#
# Instant match:  1
# Instant cancel:  4
# Cumulative match:  51
# Cumulative cancel:  519
# **************************************************
# Current step  2672
#
#
#
# Instant match:  0
# Instant cancel:  3
# Cumulative match:  51
# Cumulative cancel:  522
# **************************************************
# Current step  2673
#
#
#
# Instant match:  0
# Instant cancel:  6
# Cumulative match:  51
# Cumulative cancel:  528
# **************************************************
# Current step  2674
#
#
#
# Instant match:  0
# Instant cancel:  4
# Cumulative match:  51
# Cumulative cancel:  532
# **************************************************
# Current step  2675
#
#
#
# Instant match:  0
# Instant cancel:  6
# Cumulative match:  51
# Cumulative cancel:  538
# **************************************************
# Current step  2676
#
#
#
# Instant match:  3
# Instant cancel:  2
# Cumulative match:  54
# Cumulative cancel:  540
# **************************************************
# Current step  2677
#
#
#
# Instant match:  2
# Instant cancel:  2
# Cumulative match:  56
# Cumulative cancel:  542
# **************************************************
# Current step  2678
# Instant match:  0
# Instant cancel:  1
# Cumulative match:  56
# Cumulative cancel:  543
# **************************************************
# Current step  2679
#
#
#
# Instant match:  1
# Instant cancel:  5
# Cumulative match:  57
# Cumulative cancel:  548
# **************************************************
# Current step  2680
#
#
#
# Instant match:  0
# Instant cancel:  4
# Cumulative match:  57
# Cumulative cancel:  552
# **************************************************
# Current step  2681
#
#
#
# Instant match:  2
# Instant cancel:  2
# Cumulative match:  59
# Cumulative cancel:  554
# **************************************************
# Current step  2682
#
#
#
# Instant match:  0
# Instant cancel:  6
# Cumulative match:  59
# Cumulative cancel:  560
# **************************************************
# Current step  2683
#
#
#
# Instant match:  1
# Instant cancel:  5
# Cumulative match:  60
# Cumulative cancel:  565
# **************************************************
# Current step  2684
#
#
#
# Instant match:  0
# Instant cancel:  3
# Cumulative match:  60
# Cumulative cancel:  568
# **************************************************
# Current step  2685
#
#
#
# Instant match:  1
# Instant cancel:  5
# Cumulative match:  61
# Cumulative cancel:  573
# **************************************************
# Current step  2686
#
#
#
# Instant match:  0
# Instant cancel:  2
# Cumulative match:  61
# Cumulative cancel:  575
# **************************************************
# Current step  2687
#
#
#
# Instant match:  0
# Instant cancel:  3
# Cumulative match:  61
# Cumulative cancel:  578
# **************************************************
# Current step  2688
#
#
#
# Instant match:  1
# Instant cancel:  5
# Cumulative match:  62
# Cumulative cancel:  583
# **************************************************
# Current step  2689
#
#
#
# Instant match:  0
# Instant cancel:  4
# Cumulative match:  62
# Cumulative cancel:  587
# **************************************************
# Current step  2690
#
#
#
# Instant match:  0
# Instant cancel:  4
# Cumulative match:  62
# Cumulative cancel:  591
# **************************************************
# Current step  2691
#
#
#
# Instant match:  0
# Instant cancel:  3
# Cumulative match:  62
# Cumulative cancel:  594
# **************************************************
# Current step  2692
#
#
#
# Instant match:  0
# Instant cancel:  6
# Cumulative match:  62
# Cumulative cancel:  600
# **************************************************
# Current step  2693
#
#
#
# Instant match:  0
# Instant cancel:  6
# Cumulative match:  62
# Cumulative cancel:  606
# **************************************************
# Current step  2694
#
#
#
# Instant match:  0
# Instant cancel:  5
# Cumulative match:  62
# Cumulative cancel:  611
# **************************************************
# Current step  2695
#
#
#
# Instant match:  0
# Instant cancel:  2
# Cumulative match:  62
# Cumulative cancel:  613
# **************************************************
# Current step  2696
#
#
#
# Instant match:  0
# Instant cancel:  4
# Cumulative match:  62
# Cumulative cancel:  617
# **************************************************
# Current step  2697
#
#
#
# Instant match:  0
# Instant cancel:  3
# Cumulative match:  62
# Cumulative cancel:  620
# **************************************************
# Current step  2698
#
#
#
# Instant match:  0
# Instant cancel:  4
# Cumulative match:  62
# Cumulative cancel:  624
# **************************************************
# Current step  2699
#
#
#
# Instant match:  1
# Instant cancel:  1
# Cumulative match:  63
# Cumulative cancel:  625
# **************************************************
# Current step  2700
#
#
#
# Instant match:  0
# Instant cancel:  4
# Cumulative match:  63
# Cumulative cancel:  629
# **************************************************
# Current step  2701
#
#
#
# Instant match:  0
# Instant cancel:  5
# Cumulative match:  63
# Cumulative cancel:  634
# **************************************************
# Current step  2702
#
#
#
# Instant match:  1
# Instant cancel:  2
# Cumulative match:  64
# Cumulative cancel:  636
# **************************************************
# Current step  2703
#
#
#
# Instant match:  0
# Instant cancel:  4
# Cumulative match:  64
# Cumulative cancel:  640
# **************************************************
# Current step  2704
#
#
#
# Instant match:  0
# Instant cancel:  3
# Cumulative match:  64
# Cumulative cancel:  643
# **************************************************
# Current step  2705
#
#
#
# Instant match:  1
# Instant cancel:  1
# Cumulative match:  65
# Cumulative cancel:  644
# **************************************************
# Current step  2706
#
#
#
# Instant match:  0
# Instant cancel:  4
# Cumulative match:  65
# Cumulative cancel:  648
# **************************************************
# Current step  2707
#
#
#
# Instant match:  0
# Instant cancel:  3
# Cumulative match:  65
# Cumulative cancel:  651
# **************************************************
# Current step  2708
#
#
#
# Instant match:  0
# Instant cancel:  5
# Cumulative match:  65
# Cumulative cancel:  656
# **************************************************
# Current step  2709
#
#
#
# Instant match:  2
# Instant cancel:  3
# Cumulative match:  67
# Cumulative cancel:  659
# **************************************************
# Current step  2710
#
#
#
# Instant match:  0
# Instant cancel:  5
# Cumulative match:  67
# Cumulative cancel:  664
# **************************************************
# Current step  2711
#
#
#
# Instant match:  1
# Instant cancel:  5
# Cumulative match:  68
# Cumulative cancel:  669
# **************************************************
# Current step  2712
#
#
#
# Instant match:  0
# Instant cancel:  5
# Cumulative match:  68
# Cumulative cancel:  674
# **************************************************
# Current step  2713
#
#
#
# Instant match:  1
# Instant cancel:  2
# Cumulative match:  69
# Cumulative cancel:  676
# **************************************************
# Current step  2714
#
#
#
# Instant match:  1
# Instant cancel:  5
# Cumulative match:  70
# Cumulative cancel:  681
# **************************************************
# Current step  2715
#
#
#
# Instant match:  0
# Instant cancel:  0
# Cumulative match:  70
# Cumulative cancel:  681
# **************************************************
# Current step  2716
#
#
#
# Instant match:  0
# Instant cancel:  2
# Cumulative match:  70
# Cumulative cancel:  683
# **************************************************
# Current step  2717
#
#
#
# Instant match:  0
# Instant cancel:  4
# Cumulative match:  70
# Cumulative cancel:  687
# **************************************************
# Current step  2718
#
#
#
# Instant match:  1
# Instant cancel:  5
# Cumulative match:  71
# Cumulative cancel:  692
# **************************************************
# Current step  2719
#
#
#
# Instant match:  1
# Instant cancel:  3
# Cumulative match:  72
# Cumulative cancel:  695
# **************************************************
# Current step  2720
#
#
#
# Instant match:  1
# Instant cancel:  4
# Cumulative match:  73
# Cumulative cancel:  699
# **************************************************
# Current step  2721
#
#
#
# Instant match:  1
# Instant cancel:  4
# Cumulative match:  74
# Cumulative cancel:  703
# **************************************************
# Current step  2722
#
#
#
# Instant match:  0
# Instant cancel:  3
# Cumulative match:  74
# Cumulative cancel:  706
# **************************************************
# Current step  2723
#
#
#
# Instant match:  0
# Instant cancel:  7
# Cumulative match:  74
# Cumulative cancel:  713
# **************************************************
# Current step  2724
#
#
#
# Instant match:  0
# Instant cancel:  3
# Cumulative match:  74
# Cumulative cancel:  716
# **************************************************
# Current step  2725
#
#
#
# Instant match:  0
# Instant cancel:  7
# Cumulative match:  74
# Cumulative cancel:  723
# **************************************************
# Current step  2726
#
#
#
# Instant match:  1
# Instant cancel:  4
# Cumulative match:  75
# Cumulative cancel:  727
# **************************************************
# Current step  2727
#
#
#
# Instant match:  1
# Instant cancel:  4
# Cumulative match:  76
# Cumulative cancel:  731
# **************************************************
# Current step  2728
#
#
#
# Instant match:  0
# Instant cancel:  5
# Cumulative match:  76
# Cumulative cancel:  736
# **************************************************
# Current step  2729
#
#
#
# Instant match:  3
# Instant cancel:  5
# Cumulative match:  79
# Cumulative cancel:  741
# **************************************************
# Current step  2730
#
#
#
# Instant match:  0
# Instant cancel:  1
# Cumulative match:  79
# Cumulative cancel:  742
# **************************************************
# Current step  2731
# Instant match:  2
# Instant cancel:  5
# Cumulative match:  81
# Cumulative cancel:  747
# **************************************************
# Current step  2732
#
#
#
# Instant match:  2
# Instant cancel:  2
# Cumulative match:  83
# Cumulative cancel:  749
# **************************************************
# Current step  2733
#
#
#
# Instant match:  0
# Instant cancel:  5
# Cumulative match:  83
# Cumulative cancel:  754
# **************************************************
# Current step  2734
#
#
#
# Instant match:  0
# Instant cancel:  4
# Cumulative match:  83
# Cumulative cancel:  758
# **************************************************
# Current step  2735
#
#
#
# Instant match:  3
# Instant cancel:  2
# Cumulative match:  86
# Cumulative cancel:  760
# **************************************************
# Current step  2736
#
#
#
# Instant match:  1
# Instant cancel:  2
# Cumulative match:  87
# Cumulative cancel:  762
# **************************************************
# Current step  2737
#
#
#
# Instant match:  0
# Instant cancel:  5
# Cumulative match:  87
# Cumulative cancel:  767
# **************************************************
# Current step  2738
#
#
#
# Instant match:  1
# Instant cancel:  3
# Cumulative match:  88
# Cumulative cancel:  770
# **************************************************
# Current step  2739
#
#
#
# Instant match:  2
# Instant cancel:  2
# Cumulative match:  90
# Cumulative cancel:  772
# **************************************************
# Current step  2740
#
#
#
# Instant match:  1
# Instant cancel:  3
# Cumulative match:  91
# Cumulative cancel:  775
# **************************************************
# Current step  2741
#
#
#
# Instant match:  0
# Instant cancel:  6
# Cumulative match:  91
# Cumulative cancel:  781
# **************************************************
# Current step  2742
#
#
#
# Instant match:  0
# Instant cancel:  4
# Cumulative match:  91
# Cumulative cancel:  785
# **************************************************
# Current step  2743
#
#
#
# Instant match:  2
# Instant cancel:  4
# Cumulative match:  93
# Cumulative cancel:  789
# **************************************************
# Current step  2744
#
#
#
# Instant match:  0
# Instant cancel:  10
# Cumulative match:  93
# Cumulative cancel:  799
# **************************************************
# Current step  2745
#
#
#
# Instant match:  0
# Instant cancel:  1
# Cumulative match:  93
# Cumulative cancel:  800
# **************************************************
# Current step  2746
#
#
#
# Instant match:  1
# Instant cancel:  4
# Cumulative match:  94
# Cumulative cancel:  804
# **************************************************
# Current step  2747
#
#
#
# Instant match:  2
# Instant cancel:  3
# Cumulative match:  96
# Cumulative cancel:  807
# **************************************************
# Current step  2748
#
#
#
# Instant match:  1
# Instant cancel:  3
# Cumulative match:  97
# Cumulative cancel:  810
# **************************************************
# Current step  2749
#
#
#
# Instant match:  0
# Instant cancel:  1
# Cumulative match:  97
# Cumulative cancel:  811
# **************************************************
# Current step  2750
#
#
#
# Instant match:  1
# Instant cancel:  0
# Cumulative match:  98
# Cumulative cancel:  811
# **************************************************
# Current step  2751
#
#
#
# Instant match:  0
# Instant cancel:  6
# Cumulative match:  98
# Cumulative cancel:  817
# **************************************************
# Current step  2752
#
#
#
# Instant match:  0
# Instant cancel:  5
# Cumulative match:  98
# Cumulative cancel:  822
# **************************************************
# Current step  2753
#
#
#
# Instant match:  0
# Instant cancel:  6
# Cumulative match:  98
# Cumulative cancel:  828
# **************************************************
# Current step  2754
#
#
#
# Instant match:  0
# Instant cancel:  4
# Cumulative match:  98
# Cumulative cancel:  832
# **************************************************
# Current step  2755
#
#
#
# Instant match:  0
# Instant cancel:  5
# Cumulative match:  98
# Cumulative cancel:  837
# **************************************************
# Current step  2756
#
#
#
# Instant match:  1
# Instant cancel:  3
# Cumulative match:  99
# Cumulative cancel:  840
# **************************************************
# Current step  2757
#
#
#
# Instant match:  1
# Instant cancel:  5
# Cumulative match:  100
# Cumulative cancel:  845
# **************************************************
# Current step  2758
#
#
#
# Instant match:  0
# Instant cancel:  8
# Cumulative match:  100
# Cumulative cancel:  853
# **************************************************
# Current step  2759
#
#
#
# Instant match:  0
# Instant cancel:  7
# Cumulative match:  100
# Cumulative cancel:  860
# **************************************************
# Current step  2760
#
#
#
# Instant match:  0
# Instant cancel:  6
# Cumulative match:  100
# Cumulative cancel:  866
# **************************************************
# Current step  2761
#
#
#
# Instant match:  1
# Instant cancel:  4
# Cumulative match:  101
# Cumulative cancel:  870
# **************************************************
# Current step  2762
#
#
#
# Instant match:  0
# Instant cancel:  3
# Cumulative match:  101
# Cumulative cancel:  873
# **************************************************
# Current step  2763
#
#
#
# Instant match:  1
# Instant cancel:  5
# Cumulative match:  102
# Cumulative cancel:  878
# **************************************************
# Current step  2764
#
#
#
# Instant match:  2
# Instant cancel:  5
# Cumulative match:  104
# Cumulative cancel:  883
# **************************************************
# Current step  2765
#
#
#
# Instant match:  0
# Instant cancel:  3
# Cumulative match:  104
# Cumulative cancel:  886
# **************************************************
# Current step  2766
#
#
#
# Instant match:  0
# Instant cancel:  4
# Cumulative match:  104
# Cumulative cancel:  890
# **************************************************
# Current step  2767
#
#
#
# Instant match:  0
# Instant cancel:  5
# Cumulative match:  104
# Cumulative cancel:  895
# **************************************************
# Current step  2768
#
#
#
# Instant match:  0
# Instant cancel:  9
# Cumulative match:  104
# Cumulative cancel:  904
# **************************************************
# Current step  2769
#
#
#
# Instant match:  0
# Instant cancel:  1
# Cumulative match:  104
# Cumulative cancel:  905
# **************************************************
# Current step  2770
#
#
#
# Instant match:  2
# Instant cancel:  5
# Cumulative match:  106
# Cumulative cancel:  910
# **************************************************
# Current step  2771
#
#
#
# Instant match:  0
# Instant cancel:  5
# Cumulative match:  106
# Cumulative cancel:  915
# **************************************************
# Current step  2772
#
#
#
# Instant match:  2
# Instant cancel:  3
# Cumulative match:  108
# Cumulative cancel:  918
# **************************************************
# Current step  2773
#
#
#
# Instant match:  0
# Instant cancel:  4
# Cumulative match:  108
# Cumulative cancel:  922
# **************************************************
# Current step  2774
#
#
#
# Instant match:  0
# Instant cancel:  5
# Cumulative match:  108
# Cumulative cancel:  927
# **************************************************
# Current step  2775
#
#
#
# Instant match:  0
# Instant cancel:  4
# Cumulative match:  108
# Cumulative cancel:  931
# **************************************************
# Current step  2776
#
#
#
# Instant match:  3
# Instant cancel:  4
# Cumulative match:  111
# Cumulative cancel:  935
# **************************************************
# Current step  2777
#
#
#
# Instant match:  1
# Instant cancel:  10
# Cumulative match:  112
# Cumulative cancel:  945
# **************************************************
# Current step  2778
#
#
#
# Instant match:  1
# Instant cancel:  4
# Cumulative match:  113
# Cumulative cancel:  949
# **************************************************
# Current step  2779
#
#
#
# Instant match:  0
# Instant cancel:  7
# Cumulative match:  113
# Cumulative cancel:  956
# **************************************************
# Current step  2780
#
#
#
# Instant match:  3
# Instant cancel:  5
# Cumulative match:  116
# Cumulative cancel:  961
# **************************************************
# Current step  2781
#
#
#
# Instant match:  0
# Instant cancel:  6
# Cumulative match:  116
# Cumulative cancel:  967
# **************************************************
# Current step  2782
#
#
#
# Instant match:  1
# Instant cancel:  2
# Cumulative match:  117
# Cumulative cancel:  969
# **************************************************
# Current step  2783
#
#
#
# Instant match:  0
# Instant cancel:  10
# Cumulative match:  117
# Cumulative cancel:  979
# **************************************************
# Current step  2784
# Instant match:  0
# Instant cancel:  3
# Cumulative match:  117
# Cumulative cancel:  982
# **************************************************
# Current step  2785
#
#
#
# Instant match:  2
# Instant cancel:  5
# Cumulative match:  119
# Cumulative cancel:  987
# **************************************************
# Current step  2786
#
#
#
# Instant match:  0
# Instant cancel:  4
# Cumulative match:  119
# Cumulative cancel:  991
# **************************************************
# Current step  2787
#
#
#
# Instant match:  0
# Instant cancel:  3
# Cumulative match:  119
# Cumulative cancel:  994
# **************************************************
# Current step  2788
#
#
#
# Instant match:  0
# Instant cancel:  10
# Cumulative match:  119
# Cumulative cancel:  1004
# **************************************************
# Current step  2789
#
#
#
# Instant match:  1
# Instant cancel:  1
# Cumulative match:  120
# Cumulative cancel:  1005
# **************************************************
# Current step  2790
#
#
#
# Instant match:  0
# Instant cancel:  7
# Cumulative match:  120
# Cumulative cancel:  1012
# **************************************************
# Current step  2791
#
#
#
# Instant match:  0
# Instant cancel:  5
# Cumulative match:  120
# Cumulative cancel:  1017
# **************************************************
# Current step  2792
#
#
#
# Instant match:  0
# Instant cancel:  7
# Cumulative match:  120
# Cumulative cancel:  1024
# **************************************************
# Current step  2793
#
#
#
# Instant match:  0
# Instant cancel:  5
# Cumulative match:  120
# Cumulative cancel:  1029
# **************************************************
# Current step  2794
#
#
#
# Instant match:  1
# Instant cancel:  9
# Cumulative match:  121
# Cumulative cancel:  1038
# **************************************************
# Current step  2795
#
#
#
# Instant match:  0
# Instant cancel:  4
# Cumulative match:  121
# Cumulative cancel:  1042
# **************************************************
# Current step  2796
#
#
#
# Instant match:  0
# Instant cancel:  7
# Cumulative match:  121
# Cumulative cancel:  1049
# **************************************************
# Current step  2797
#
#
#
# Instant match:  1
# Instant cancel:  9
# Cumulative match:  122
# Cumulative cancel:  1058
# **************************************************
# Current step  2798
#
#
#
# Instant match:  0
# Instant cancel:  4
# Cumulative match:  122
# Cumulative cancel:  1062
# **************************************************
# Current step  2799
#
#
#
# Instant match:  0
# Instant cancel:  1
# Cumulative match:  122
# Cumulative cancel:  1063
# **************************************************
# Current step  2800
#
#
#
# Instant match:  0
# Instant cancel:  6
# Cumulative match:  122
# Cumulative cancel:  1069
# **************************************************
# Current step  2801
#
#
#
# Instant match:  2
# Instant cancel:  6
# Cumulative match:  124
# Cumulative cancel:  1075
# **************************************************
# Current step  2802
#
#
#
# Instant match:  1
# Instant cancel:  5
# Cumulative match:  125
# Cumulative cancel:  1080
# **************************************************
# Current step  2803
#
#
#
# Instant match:  1
# Instant cancel:  3
# Cumulative match:  126
# Cumulative cancel:  1083
# **************************************************
# Current step  2804
#
#
#
# Instant match:  1
# Instant cancel:  2
# Cumulative match:  127
# Cumulative cancel:  1085
# **************************************************
# Current step  2805
#
#
#
# Instant match:  0
# Instant cancel:  5
# Cumulative match:  127
# Cumulative cancel:  1090
# **************************************************
# Current step  2806
#
#
#
# Instant match:  1
# Instant cancel:  2
# Cumulative match:  128
# Cumulative cancel:  1092
# **************************************************
# Current step  2807
#
#
#
# Instant match:  2
# Instant cancel:  5
# Cumulative match:  130
# Cumulative cancel:  1097
# **************************************************
# Current step  2808
#
#
#
# Instant match:  0
# Instant cancel:  2
# Cumulative match:  130
# Cumulative cancel:  1099
# **************************************************
# Current step  2809
#
#
#
# Instant match:  0
# Instant cancel:  6
# Cumulative match:  130
# Cumulative cancel:  1105
# **************************************************
# Current step  2810
#
#
#
# Instant match:  1
# Instant cancel:  4
# Cumulative match:  131
# Cumulative cancel:  1109
# **************************************************
# Current step  2811
#
#
#
# Instant match:  0
# Instant cancel:  6
# Cumulative match:  131
# Cumulative cancel:  1115
# **************************************************
# Current step  2812
#
#
#
# Instant match:  1
# Instant cancel:  7
# Cumulative match:  132
# Cumulative cancel:  1122
# **************************************************
# Current step  2813
#
#
#
# Instant match:  0
# Instant cancel:  2
# Cumulative match:  132
# Cumulative cancel:  1124
# **************************************************
# Current step  2814
#
#
#
# Instant match:  1
# Instant cancel:  9
# Cumulative match:  133
# Cumulative cancel:  1133
# **************************************************
# Current step  2815
#
#
#
# Instant match:  0
# Instant cancel:  10
# Cumulative match:  133
# Cumulative cancel:  1143
# **************************************************
# Current step  2816
#
#
#
# Instant match:  1
# Instant cancel:  7
# Cumulative match:  134
# Cumulative cancel:  1150
# **************************************************
# Current step  2817
#
#
#
# Instant match:  0
# Instant cancel:  3
# Cumulative match:  134
# Cumulative cancel:  1153
# **************************************************
# Current step  2818
#
#
#
# Instant match:  0
# Instant cancel:  6
# Cumulative match:  134
# Cumulative cancel:  1159
# **************************************************
# Current step  2819
#
#
#
# Instant match:  1
# Instant cancel:  2
# Cumulative match:  135
# Cumulative cancel:  1161
# **************************************************
# Current step  2820
#
#
#
# Instant match:  1
# Instant cancel:  6
# Cumulative match:  136
# Cumulative cancel:  1167
# **************************************************
# Current step  2821
#
#
#
# Instant match:  1
# Instant cancel:  7
# Cumulative match:  137
# Cumulative cancel:  1174
# **************************************************
# Current step  2822
#
#
#
# Instant match:  0
# Instant cancel:  1
# Cumulative match:  137
# Cumulative cancel:  1175
# **************************************************
# Current step  2823
#
#
#
# Instant match:  0
# Instant cancel:  4
# Cumulative match:  137
# Cumulative cancel:  1179
# **************************************************
# Current step  2824
#
#
#
# Instant match:  0
# Instant cancel:  6
# Cumulative match:  137
# Cumulative cancel:  1185
# **************************************************
# Current step  2825
#
#
#
# Instant match:  1
# Instant cancel:  5
# Cumulative match:  138
# Cumulative cancel:  1190
# **************************************************
# Current step  2826
#
#
#
# Instant match:  2
# Instant cancel:  6
# Cumulative match:  140
# Cumulative cancel:  1196
# **************************************************
# Current step  2827
#
#
#
# Instant match:  2
# Instant cancel:  6
# Cumulative match:  142
# Cumulative cancel:  1202
# **************************************************
# Current step  2828
#
#
#
# Instant match:  0
# Instant cancel:  5
# Cumulative match:  142
# Cumulative cancel:  1207
# **************************************************
# Current step  2829
#
#
#
# Instant match:  2
# Instant cancel:  3
# Cumulative match:  144
# Cumulative cancel:  1210
# **************************************************
# Current step  2830
#
#
#
# Instant match:  1
# Instant cancel:  4
# Cumulative match:  145
# Cumulative cancel:  1214
# **************************************************
# Current step  2831
#
#
#
# Instant match:  6
# Instant cancel:  6
# Cumulative match:  151
# Cumulative cancel:  1220
# **************************************************
# Current step  2832
#
#
#
# Instant match:  1
# Instant cancel:  5
# Cumulative match:  152
# Cumulative cancel:  1225
# **************************************************
# Current step  2833
#
#
#
# Instant match:  1
# Instant cancel:  4
# Cumulative match:  153
# Cumulative cancel:  1229
# **************************************************
# Current step  2834
#
#
#
# Instant match:  4
# Instant cancel:  5
# Cumulative match:  157
# Cumulative cancel:  1234
# **************************************************
# Current step  2835
#
#
#
# Instant match:  0
# Instant cancel:  9
# Cumulative match:  157
# Cumulative cancel:  1243
# **************************************************
# Current step  2836
# Instant match:  0
# Instant cancel:  8
# Cumulative match:  157
# Cumulative cancel:  1251
# **************************************************
# Current step  2837
#
#
#
# Instant match:  0
# Instant cancel:  5
# Cumulative match:  157
# Cumulative cancel:  1256
# **************************************************
# Current step  2838
#
#
#
# Instant match:  2
# Instant cancel:  7
# Cumulative match:  159
# Cumulative cancel:  1263
# **************************************************
# Current step  2839
#
#
#
# Instant match:  0
# Instant cancel:  6
# Cumulative match:  159
# Cumulative cancel:  1269
# **************************************************
# Current step  2840
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-89-4583da4bf15f> in <module>
#     140     Matching_result['A']=One2One_Matching(Profit_A)
#     141
# --> 142     Matching_result['B']=One2One_Matching(Profit_B)
#     143
#     144
#
# <ipython-input-3-3f05d04e5485> in One2One_Matching(Utility)
#      36          model += pulp.lpSum([X[(O, D)] for O in Utility_[D].keys()]) <=1
#      37
# ---> 38     model.solve()
#      39
#      40     result={}
#
# /opt/anaconda3/lib/python3.8/site-packages/pulp/pulp.py in solve(self, solver, **kwargs)
#    1875         # time it
#    1876         self.startClock()
# -> 1877         status = solver.actualSolve(self, **kwargs)
#    1878         self.stopClock()
#    1879         self.restoreObjective(wasNone, dummyVar)
#
# /opt/anaconda3/lib/python3.8/site-packages/pulp/apis/coin_api.py in actualSolve(self, lp, **kwargs)
#     135     def actualSolve(self, lp, **kwargs):
#     136         """Solve a well formulated lp problem"""
# --> 137         return self.solve_CBC(lp, **kwargs)
#     138
#     139     def available(self):
#
# /opt/anaconda3/lib/python3.8/site-packages/pulp/apis/coin_api.py in solve_CBC(self, lp, use_mps)
#     193         args.extend(cmds[1:].split())
#     194         cbc = subprocess.Popen(args, stdout=pipe, stderr=pipe, stdin=devnull)
# --> 195         if cbc.wait() != 0:
#     196             if pipe:
#     197                 pipe.close()
#
# /opt/anaconda3/lib/python3.8/subprocess.py in wait(self, timeout)
#    1081             endtime = _time() + timeout
#    1082         try:
# -> 1083             return self._wait(timeout=timeout)
#    1084         except KeyboardInterrupt:
#    1085             # https://bugs.python.org/issue25942
#
# /opt/anaconda3/lib/python3.8/subprocess.py in _wait(self, timeout)
#    1806                         if self.returncode is not None:
#    1807                             break  # Another thread waited.
# -> 1808                         (pid, sts) = self._try_wait(0)
#    1809                         # Check the pid and loop as waitpid has been known to
#    1810                         # return 0 even without WNOHANG in odd situations.
#
# /opt/anaconda3/lib/python3.8/subprocess.py in _try_wait(self, wait_flags)
#    1764             """All callers to this function MUST hold self._waitpid_lock."""
#    1765             try:
# -> 1766                 (pid, sts) = os.waitpid(self.pid, wait_flags)
#    1767             except ChildProcessError:
#    1768                 # This happens if SIGCLD is set to be ignored or waiting
#
# KeyboardInterrupt:
